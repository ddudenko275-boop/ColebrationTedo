# %% [markdown]
# # PD Calibration Legacy Notebook
#
# This archived notebook has been replaced by `pd_calibration.ipynb`, which contains the current English version of the study: calibrated PD comparison, out-of-time validation, binomial z-stat diagnostics, fixed master-scale analysis, and Basel-style RWA/capital impact.
#
# Use `pd_calibration.ipynb` as the maintained research notebook.
